# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) #for testing, decrease this number to 50
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) #for testing, decrease this number to 50
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

#print(cities)
# Out:
# Number of cities in the list: 637

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL - Use openweather API 2.5
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Unit: standard or imperial
unit = "imperial"

# Define a limit for the number of results (adjust as needed)
limit = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&limit={limit}&appid={weather_api_key}&units={unit}"
    #f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        #print(f"{city} found")
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | laojunmiao
# Processing Record 2 of Set 1 | tobruk
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | rikaze
# Processing Record 5 of Set 1 | sitka
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 1 | freetown
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | grytviken
# Processing Record 13 of Set 1 | olavarria
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto lempira
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | udachny
# Processing Record 18 of Set 1 | mancora
# Processing Record 19 of Set 1 | greenville
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | letterkenny
# Processing Record 23 of Set 1 | mejit
# Processing Record 24 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 25 of Set 1 | utrik
# Processing Record 26 of Set 1 | huarmey
# Processing Record 27 of Set 1 | nikshahr
# City not found. Skipping...
# Processing Record 28 of Set 1 | ihsaniye
# Processing Record 29 of Set 1 | mirny
# Processing Record 30 of Set 1 | hammerfest
# Processing Record 31 of Set 1 | klyuchi
# Processing Record 32 of Set 1 | tolanaro
# Processing Record 33 of Set 1 | abasolo
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | rawson
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | savonlinna
# Processing Record 40 of Set 1 | west island
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | cunha
# Processing Record 43 of Set 1 | sarangani
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | port mathurin
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 48 of Set 1 | ola
# Processing Record 49 of Set 1 | invercargill
# Processing Record 50 of Set 1 | papatowai
# Processing Record 0 of Set 2 | bassila
# Processing Record 1 of Set 2 | hamilton
# Processing Record 2 of Set 2 | pacific grove
# Processing Record 3 of Set 2 | labuan
# Processing Record 4 of Set 2 | wailua homesteads
# Processing Record 5 of Set 2 | bhinmal
# Processing Record 6 of Set 2 | badger
# Processing Record 7 of Set 2 | adamstown
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | iranshahr
# Processing Record 10 of Set 2 | hadibu
# Processing Record 11 of Set 2 | nar'yan-mar
# Processing Record 12 of Set 2 | tomiya
# Processing Record 13 of Set 2 | fisterra
# Processing Record 14 of Set 2 | ostrzeszow
# Processing Record 15 of Set 2 | al kharijah
# Processing Record 16 of Set 2 | constantia
# Processing Record 17 of Set 2 | vilyuchinsk
# Processing Record 18 of Set 2 | chonchi
# Processing Record 19 of Set 2 | piikkio
# Processing Record 20 of Set 2 | la passe
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | lakatoro
# Processing Record 23 of Set 2 | raja
# Processing Record 24 of Set 2 | uturoa
# Processing Record 25 of Set 2 | kabul
# Processing Record 26 of Set 2 | sisimiut
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | santa vitoria do palmar
# Processing Record 29 of Set 2 | le vauclin
# Processing Record 30 of Set 2 | olonkinbyen
# Processing Record 31 of Set 2 | ol'gino
# Processing Record 32 of Set 2 | lihue
# Processing Record 33 of Set 2 | ochakiv
# Processing Record 34 of Set 2 | kailua-kona
# Processing Record 35 of Set 2 | gaspe
# Processing Record 36 of Set 2 | blackmans bay
# Processing Record 37 of Set 2 | placido de castro
# Processing Record 38 of Set 2 | kerikeri
# Processing Record 39 of Set 2 | moree
# Processing Record 40 of Set 2 | isafjordur
# Processing Record 41 of Set 2 | tashtyp
# Processing Record 42 of Set 2 | vilhena
# Processing Record 43 of Set 2 | nouadhibou
# Processing Record 44 of Set 2 | el porvenir
# Processing Record 45 of Set 2 | dongcun
# Processing Record 46 of Set 2 | crane
# Processing Record 47 of Set 2 | papao
# Processing Record 48 of Set 2 | nadi
# Processing Record 49 of Set 2 | birjand
# Processing Record 0 of Set 3 | sosnovo-ozerskoye
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | conceicao da barra
# Processing Record 4 of Set 3 | dodoma
# Processing Record 5 of Set 3 | whitehorse
# Processing Record 6 of Set 3 | zastron
# Processing Record 7 of Set 3 | cabo san lucas
# Processing Record 8 of Set 3 | kapuskasing
# Processing Record 9 of Set 3 | huaraz
# Processing Record 10 of Set 3 | amga
# Processing Record 11 of Set 3 | koungou
# Processing Record 12 of Set 3 | keflavik
# Processing Record 13 of Set 3 | gimbi
# Processing Record 14 of Set 3 | bandar-e lengeh
# Processing Record 15 of Set 3 | along
# Processing Record 16 of Set 3 | sept-iles
# Processing Record 17 of Set 3 | reggane
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | rio grande
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | simanggang
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | les anglais
# Processing Record 24 of Set 3 | sao miguel do araguaia
# Processing Record 25 of Set 3 | boende
# Processing Record 26 of Set 3 | susuman
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | hood river
# Processing Record 29 of Set 3 | acapulco de juarez
# Processing Record 30 of Set 3 | urangan
# Processing Record 31 of Set 3 | pandan
# Processing Record 32 of Set 3 | biswan
# Processing Record 33 of Set 3 | laguna
# Processing Record 34 of Set 3 | tual
# Processing Record 35 of Set 3 | gisborne
# Processing Record 36 of Set 3 | sola
# Processing Record 37 of Set 3 | remire-montjoly
# Processing Record 38 of Set 3 | lagunas
# Processing Record 39 of Set 3 | san antonio de pale
# Processing Record 40 of Set 3 | launceston
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | puerto aysen
# Processing Record 43 of Set 3 | atafu village
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | carlos barbosa
# Processing Record 46 of Set 3 | farah
# Processing Record 47 of Set 3 | malanville
# Processing Record 48 of Set 3 | kingston
# Processing Record 49 of Set 3 | stanley
# Processing Record 0 of Set 4 | itoman
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | mashhad
# Processing Record 3 of Set 4 | koppies
# Processing Record 4 of Set 4 | khovd
# Processing Record 5 of Set 4 | caratinga
# Processing Record 6 of Set 4 | alo
# Processing Record 7 of Set 4 | bigadic
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 10 of Set 4 | ishinomaki
# Processing Record 11 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 4 | tazovsky
# Processing Record 13 of Set 4 | la grande
# Processing Record 14 of Set 4 | masaka
# Processing Record 15 of Set 4 | nyrob
# Processing Record 16 of Set 4 | iquique
# Processing Record 17 of Set 4 | nuevitas
# Processing Record 18 of Set 4 | dudinka
# Processing Record 19 of Set 4 | whakatane
# Processing Record 20 of Set 4 | fale old settlement
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | alliance
# Processing Record 23 of Set 4 | mumford
# Processing Record 24 of Set 4 | college
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | barra de santo antonio
# Processing Record 27 of Set 4 | port moresby
# Processing Record 28 of Set 4 | berezovyy
# Processing Record 29 of Set 4 | vorkuta
# Processing Record 30 of Set 4 | laurel
# Processing Record 31 of Set 4 | beypazari
# Processing Record 32 of Set 4 | skurup
# Processing Record 33 of Set 4 | peruibe
# Processing Record 34 of Set 4 | sanctuary point
# Processing Record 35 of Set 4 | sao joao evangelista
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | satsuma
# Processing Record 38 of Set 4 | malmesbury
# Processing Record 39 of Set 4 | qamdo
# Processing Record 40 of Set 4 | krasnapollye
# Processing Record 41 of Set 4 | nogliki
# Processing Record 42 of Set 4 | shush
# Processing Record 43 of Set 4 | burlington
# Processing Record 44 of Set 4 | penzance
# Processing Record 45 of Set 4 | longyearbyen
# Processing Record 46 of Set 4 | greystones
# Processing Record 47 of Set 4 | kenai
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | lata
# Processing Record 0 of Set 5 | taltal
# Processing Record 1 of Set 5 | bousso
# Processing Record 2 of Set 5 | zajecar
# Processing Record 3 of Set 5 | apodi
# Processing Record 4 of Set 5 | la mira
# Processing Record 5 of Set 5 | sao gabriel da cachoeira
# Processing Record 6 of Set 5 | weno
# Processing Record 7 of Set 5 | villa gesell
# Processing Record 8 of Set 5 | amungan
# Processing Record 9 of Set 5 | saguenay
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | chos malal
# Processing Record 12 of Set 5 | fort bragg
# Processing Record 13 of Set 5 | weyburn
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | dzhangala
# Processing Record 16 of Set 5 | illizi
# Processing Record 17 of Set 5 | sanguem
# Processing Record 18 of Set 5 | beaufort west
# Processing Record 19 of Set 5 | richmond
# Processing Record 20 of Set 5 | broome
# Processing Record 21 of Set 5 | berdigestyakh
# Processing Record 22 of Set 5 | pathein
# Processing Record 23 of Set 5 | belmonte
# Processing Record 24 of Set 5 | garachico
# Processing Record 25 of Set 5 | harstad
# Processing Record 26 of Set 5 | akureyri
# Processing Record 27 of Set 5 | lusaka
# Processing Record 28 of Set 5 | general acha
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | miramichi
# Processing Record 31 of Set 5 | anadyr
# Processing Record 32 of Set 5 | south hedland
# Processing Record 33 of Set 5 | portage la prairie
# Processing Record 34 of Set 5 | partizanske
# Processing Record 35 of Set 5 | san jose del guaviare
# Processing Record 36 of Set 5 | daru
# Processing Record 37 of Set 5 | vuosaari
# Processing Record 38 of Set 5 | boali
# Processing Record 39 of Set 5 | chotebor
# Processing Record 40 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 5 | marsaskala
# City not found. Skipping...
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 43 of Set 5 | luebo
# Processing Record 44 of Set 5 | tralee
# Processing Record 45 of Set 5 | segou
# Processing Record 46 of Set 5 | walvis bay
# Processing Record 47 of Set 5 | sarmiento
# Processing Record 48 of Set 5 | kaedi
# Processing Record 49 of Set 5 | quellon
# Processing Record 0 of Set 6 | pirawa
# Processing Record 1 of Set 6 | nova sintra
# Processing Record 2 of Set 6 | piggotts
# Processing Record 3 of Set 6 | kapa'a
# Processing Record 4 of Set 6 | sinabang
# Processing Record 5 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 6 | callao
# Processing Record 7 of Set 6 | rundu
# Processing Record 8 of Set 6 | carutapera
# Processing Record 9 of Set 6 | urbana
# Processing Record 10 of Set 6 | talara
# Processing Record 11 of Set 6 | wesley hills
# Processing Record 12 of Set 6 | la ronge
# Processing Record 13 of Set 6 | suoyarvi
# Processing Record 14 of Set 6 | port douglas
# Processing Record 15 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 16 of Set 6 | namibe
# Processing Record 17 of Set 6 | floro
# Processing Record 18 of Set 6 | flying fish cove
# Processing Record 19 of Set 6 | kroya
# Processing Record 20 of Set 6 | isakogorka
# City not found. Skipping...
# Processing Record 21 of Set 6 | east london
# Processing Record 22 of Set 6 | conduaga
# Processing Record 23 of Set 6 | markovo
# Processing Record 24 of Set 6 | bonthe
# Processing Record 25 of Set 6 | vila do maio
# Processing Record 26 of Set 6 | madimba
# Processing Record 27 of Set 6 | pervomayskoye
# Processing Record 28 of Set 6 | gwadar
# Processing Record 29 of Set 6 | mount pearl
# Processing Record 30 of Set 6 | belomorsk
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | burang
# Processing Record 34 of Set 6 | antsiranana
# Processing Record 35 of Set 6 | praia
# Processing Record 36 of Set 6 | koneurgench
# City not found. Skipping...
# Processing Record 37 of Set 6 | westport
# Processing Record 38 of Set 6 | dokkum
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | vilyuysk
# Processing Record 41 of Set 6 | juruti
# Processing Record 42 of Set 6 | holualoa
# Processing Record 43 of Set 6 | vadso
# Processing Record 44 of Set 6 | shimoda
# Processing Record 45 of Set 6 | chaumont
# Processing Record 46 of Set 6 | galliano
# Processing Record 47 of Set 6 | makrana
# Processing Record 48 of Set 6 | idri
# Processing Record 49 of Set 6 | vorgashor
# Processing Record 0 of Set 7 | piti village
# Processing Record 1 of Set 7 | okha
# Processing Record 2 of Set 7 | likiep
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | al mijlad
# Processing Record 5 of Set 7 | ar ruseris
# Processing Record 6 of Set 7 | taroa
# Processing Record 7 of Set 7 | novaya ladoga
# Processing Record 8 of Set 7 | oranjemund
# Processing Record 9 of Set 7 | santa cruz
# Processing Record 10 of Set 7 | bardai
# Processing Record 11 of Set 7 | as saffaniyah
# Processing Record 12 of Set 7 | zhalantun
# Processing Record 13 of Set 7 | ataq
# Processing Record 14 of Set 7 | mar del plata
# Processing Record 15 of Set 7 | ardestan
# Processing Record 16 of Set 7 | kharp
# Processing Record 17 of Set 7 | uhlingen-birkendorf
# Processing Record 18 of Set 7 | negara
# Processing Record 19 of Set 7 | west bay
# Processing Record 20 of Set 7 | levuka
# Processing Record 21 of Set 7 | victoria de durango
# Processing Record 22 of Set 7 | la paz
# Processing Record 23 of Set 7 | thunder bay
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | nueva gerona
# Processing Record 26 of Set 7 | mlalo
# Processing Record 27 of Set 7 | iskateley
# Processing Record 28 of Set 7 | bodaybo
# Processing Record 29 of Set 7 | st. john's
# Processing Record 30 of Set 7 | sukhinichi
# Processing Record 31 of Set 7 | nema
# Processing Record 32 of Set 7 | aykhal
# Processing Record 33 of Set 7 | karasu
# Processing Record 34 of Set 7 | arno
# Processing Record 35 of Set 7 | hoopeston
# Processing Record 36 of Set 7 | socorro
# Processing Record 37 of Set 7 | mezhdurechenskiy
# Processing Record 38 of Set 7 | fortuna
# Processing Record 39 of Set 7 | magadan
# Processing Record 40 of Set 7 | tulum
# Processing Record 41 of Set 7 | port saint john's
# Processing Record 42 of Set 7 | usol'ye
# Processing Record 43 of Set 7 | san fernando del valle de catamarca
# Processing Record 44 of Set 7 | baiona
# Processing Record 45 of Set 7 | poletayevo
# Processing Record 46 of Set 7 | fort mcmurray
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | san pedro
# Processing Record 49 of Set 7 | santa maria
# Processing Record 0 of Set 8 | bratsk
# Processing Record 1 of Set 8 | keetmanshoop
# Processing Record 2 of Set 8 | haiku-pauwela
# Processing Record 3 of Set 8 | saipan
# Processing Record 4 of Set 8 | fonadhoo
# City not found. Skipping...
# Processing Record 5 of Set 8 | eraan
# Processing Record 6 of Set 8 | ust-nera
# Processing Record 7 of Set 8 | enschede
# Processing Record 8 of Set 8 | touros
# Processing Record 9 of Set 8 | new norfolk
# Processing Record 10 of Set 8 | sanya
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | zhangye
# Processing Record 13 of Set 8 | lesogorsk
# Processing Record 14 of Set 8 | jwaneng
# Processing Record 15 of Set 8 | santa sylvina
# Processing Record 16 of Set 8 | pangody
# Processing Record 17 of Set 8 | saldanha
# Processing Record 18 of Set 8 | uruzgan
# Processing Record 19 of Set 8 | kuta
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | dogondoutchi
# Processing Record 22 of Set 8 | sao jose da coroa grande
# Processing Record 23 of Set 8 | pennadam
# Processing Record 24 of Set 8 | freeport
# Processing Record 25 of Set 8 | horta
# Processing Record 26 of Set 8 | mahina
# Processing Record 27 of Set 8 | gadzhiyevo
# Processing Record 28 of Set 8 | poronaysk
# Processing Record 29 of Set 8 | muravlenko
# Processing Record 30 of Set 8 | escarcega
# Processing Record 31 of Set 8 | santa ana
# Processing Record 32 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 33 of Set 8 | minas de marcona
# Processing Record 34 of Set 8 | saarijarvi
# Processing Record 35 of Set 8 | san-pedro
# Processing Record 36 of Set 8 | hawaiian paradise park
# Processing Record 37 of Set 8 | turpan
# Processing Record 38 of Set 8 | nacala
# Processing Record 39 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | brady
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | san borja
# Processing Record 44 of Set 8 | bati
# Processing Record 45 of Set 8 | mongo
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | menaka
# Processing Record 48 of Set 8 | clevelandia
# Processing Record 49 of Set 8 | khandyga
# Processing Record 0 of Set 9 | san angelo
# Processing Record 1 of Set 9 | sevastopol
# Processing Record 2 of Set 9 | port alberni
# Processing Record 3 of Set 9 | ternate
# Processing Record 4 of Set 9 | asau village
# City not found. Skipping...
# Processing Record 5 of Set 9 | qui nhon
# Processing Record 6 of Set 9 | aasiaat
# Processing Record 7 of Set 9 | poteau
# Processing Record 8 of Set 9 | mtambile
# Processing Record 9 of Set 9 | polyarnyy
# Processing Record 10 of Set 9 | howard springs
# Processing Record 11 of Set 9 | paragould
# Processing Record 12 of Set 9 | nadym
# Processing Record 13 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 9 | chonglong
# Processing Record 15 of Set 9 | park city
# Processing Record 16 of Set 9 | enewetak
# Processing Record 17 of Set 9 | sao vicente
# Processing Record 18 of Set 9 | guiyang
# Processing Record 19 of Set 9 | soran
# Processing Record 20 of Set 9 | bodo
# Processing Record 21 of Set 9 | littlefield
# Processing Record 22 of Set 9 | al ghayzah
# Processing Record 23 of Set 9 | hilo
# Processing Record 24 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 25 of Set 9 | ulanhot
# Processing Record 26 of Set 9 | jalai nur
# Processing Record 27 of Set 9 | kuqa
# Processing Record 28 of Set 9 | qulsary
# Processing Record 29 of Set 9 | sogndal
# Processing Record 30 of Set 9 | buedu
# Processing Record 31 of Set 9 | ghat
# Processing Record 32 of Set 9 | port alfred
# Processing Record 33 of Set 9 | al balyana
# Processing Record 34 of Set 9 | chulakkurgan
# Processing Record 35 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 36 of Set 9 | taoudenni
# Processing Record 37 of Set 9 | bulungu
# Processing Record 38 of Set 9 | shohimardon
# Processing Record 39 of Set 9 | alamos
# Processing Record 40 of Set 9 | antofagasta
# Processing Record 41 of Set 9 | jinchang
# Processing Record 42 of Set 9 | karungdong
# Processing Record 43 of Set 9 | guozhen
# Processing Record 44 of Set 9 | ta`u
# Processing Record 45 of Set 9 | abepura
# Processing Record 46 of Set 9 | orenburg
# Processing Record 47 of Set 9 | jamaame
# Processing Record 48 of Set 9 | muisne
# Processing Record 49 of Set 9 | aripuana
# Processing Record 0 of Set 10 | santa elena de uairen
# Processing Record 1 of Set 10 | cadale
# Processing Record 2 of Set 10 | bikenibeu village
# Processing Record 3 of Set 10 | ain beni mathar
# City not found. Skipping...
# Processing Record 4 of Set 10 | amahai
# Processing Record 5 of Set 10 | ceerigaabo
# Processing Record 6 of Set 10 | mthatha
# Processing Record 7 of Set 10 | tsiombe
# Processing Record 8 of Set 10 | isla vista
# Processing Record 9 of Set 10 | boyolangu
# Processing Record 10 of Set 10 | bouarfa
# Processing Record 11 of Set 10 | dickinson
# Processing Record 12 of Set 10 | aksu
# Processing Record 13 of Set 10 | lae
# Processing Record 14 of Set 10 | colonia
# Processing Record 15 of Set 10 | tauranga
# Processing Record 16 of Set 10 | moapa valley
# Processing Record 17 of Set 10 | afaahiti
# Processing Record 18 of Set 10 | orange walk
# Processing Record 19 of Set 10 | lillehammer
# Processing Record 20 of Set 10 | salym
# Processing Record 21 of Set 10 | pariaman
# Processing Record 22 of Set 10 | bamboo flat
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | dakhla
# Processing Record 25 of Set 10 | taikang
# Processing Record 26 of Set 10 | sulecin
# Processing Record 27 of Set 10 | kiiminki
# Processing Record 28 of Set 10 | margherita
# Processing Record 29 of Set 10 | krasnyy kut
# Processing Record 30 of Set 10 | ban dung
# Processing Record 31 of Set 10 | carbonear
# Processing Record 32 of Set 10 | urzhar
# Processing Record 33 of Set 10 | yaren
# Processing Record 34 of Set 10 | menongue
# Processing Record 35 of Set 10 | xilin hot
# Processing Record 36 of Set 10 | mao
# Processing Record 37 of Set 10 | kidal
# Processing Record 38 of Set 10 | bulgan
# Processing Record 39 of Set 10 | naze
# Processing Record 40 of Set 10 | lake geneva
# Processing Record 41 of Set 10 | arraial do cabo
# Processing Record 42 of Set 10 | eforie sud
# Processing Record 43 of Set 10 | ulan bator
# Processing Record 44 of Set 10 | belyy yar
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | maracaju
# Processing Record 47 of Set 10 | amble
# Processing Record 48 of Set 10 | usogorsk
# Processing Record 49 of Set 10 | port hueneme
# Processing Record 0 of Set 11 | boke
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | shambu
# Processing Record 3 of Set 11 | port lincoln
# Processing Record 4 of Set 11 | uray
# Processing Record 5 of Set 11 | anisoc
# Processing Record 6 of Set 11 | rong kwang
# Processing Record 7 of Set 11 | sawang daen din
# Processing Record 8 of Set 11 | fort-shevchenko
# Processing Record 9 of Set 11 | mont-laurier
# Processing Record 10 of Set 11 | island harbour
# Processing Record 11 of Set 11 | antigonish
# Processing Record 12 of Set 11 | mathis
# Processing Record 13 of Set 11 | edmundston
# Processing Record 14 of Set 11 | syktyvkar
# Processing Record 15 of Set 11 | soio
# Processing Record 16 of Set 11 | ostersund
# Processing Record 17 of Set 11 | santa terezinha
# Processing Record 18 of Set 11 | ceeldheer
# Processing Record 19 of Set 11 | newman
# Processing Record 20 of Set 11 | lazaro cardenas
# Processing Record 21 of Set 11 | tubarjal
# Processing Record 22 of Set 11 | atherton
# Processing Record 23 of Set 11 | port-cartier
# Processing Record 24 of Set 11 | vila velha
# Processing Record 25 of Set 11 | toliara
# Processing Record 26 of Set 11 | alaghsas
# Processing Record 27 of Set 11 | pierre
# Processing Record 28 of Set 11 | hami
# Processing Record 29 of Set 11 | guerrero negro
# Processing Record 30 of Set 11 | severo-yeniseyskiy
# Processing Record 31 of Set 11 | howrah
# Processing Record 32 of Set 11 | shchyolkino
# Processing Record 33 of Set 11 | winslow
# Processing Record 34 of Set 11 | opuwo
# Processing Record 35 of Set 11 | ito
# Processing Record 36 of Set 11 | arawa
# Processing Record 37 of Set 11 | kralendijk
# Processing Record 38 of Set 11 | lib
# Processing Record 39 of Set 11 | northam
# Processing Record 40 of Set 11 | porto novo
# Processing Record 41 of Set 11 | axim
# Processing Record 42 of Set 11 | mizdah
# Processing Record 43 of Set 11 | chandler
# Processing Record 44 of Set 11 | hanko
# Processing Record 45 of Set 11 | alofi
# Processing Record 46 of Set 11 | paracuru
# Processing Record 47 of Set 11 | tahe
# Processing Record 48 of Set 11 | fortaleza
# Processing Record 49 of Set 11 | arica
# Processing Record 0 of Set 12 | nishinoomote
# Processing Record 1 of Set 12 | havre
# Processing Record 2 of Set 12 | sao borja
# Processing Record 3 of Set 12 | zaragoza
# Processing Record 4 of Set 12 | posadas
# Processing Record 5 of Set 12 | mahajanga
# Processing Record 6 of Set 12 | kirkwood
# Processing Record 7 of Set 12 | san luis de la loma
# Processing Record 8 of Set 12 | baruun-urt
# Processing Record 9 of Set 12 | khilok
# Processing Record 10 of Set 12 | springs
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | at taraf
# Processing Record 13 of Set 12 | yumbe
# Processing Record 14 of Set 12 | selfoss
# Processing Record 15 of Set 12 | mili
# Processing Record 16 of Set 12 | umm kaddadah
# Processing Record 17 of Set 12 | bouar
# Processing Record 18 of Set 12 | north bay
# Processing Record 19 of Set 12 | fuglafjordur
# Processing Record 20 of Set 12 | khash
# Processing Record 21 of Set 12 | saudarkrokur
# Processing Record 22 of Set 12 | east falmouth
# Processing Record 23 of Set 12 | praia da vitoria
# Processing Record 24 of Set 12 | kulu
# Processing Record 25 of Set 12 | talnakh
# Processing Record 26 of Set 12 | newport
# Processing Record 27 of Set 12 | samarra'
# City not found. Skipping...
# Processing Record 28 of Set 12 | saint-francois
# Processing Record 29 of Set 12 | las khorey
# Processing Record 30 of Set 12 | queenstown
# Processing Record 31 of Set 12 | yangjiang
# Processing Record 32 of Set 12 | shawinigan
# Processing Record 33 of Set 12 | faya-largeau
# Processing Record 34 of Set 12 | lucapa
# Processing Record 35 of Set 12 | votuporanga
# Processing Record 36 of Set 12 | lycksele
# Processing Record 37 of Set 12 | volcan
# Processing Record 38 of Set 12 | kalmunai
# Processing Record 39 of Set 12 | labytnangi
# Processing Record 40 of Set 12 | al 'alamayn
# City not found. Skipping...
# Processing Record 41 of Set 12 | dubovskoye
# Processing Record 42 of Set 12 | tacuarembo
# Processing Record 43 of Set 12 | nadvoitsy
# Processing Record 44 of Set 12 | kourou
# Processing Record 45 of Set 12 | bubaque
# Processing Record 46 of Set 12 | lagos
# Processing Record 47 of Set 12 | greymouth
# Processing Record 48 of Set 12 | east ballina
# Processing Record 49 of Set 12 | kuala belait
# Processing Record 0 of Set 13 | nemuro
# Processing Record 1 of Set 13 | villa del totoral
# Processing Record 2 of Set 13 | jardim do serido
# Processing Record 3 of Set 13 | alexandria
# Processing Record 4 of Set 13 | kruisfontein
# Processing Record 5 of Set 13 | jogeva
# Processing Record 6 of Set 13 | prince george
# Processing Record 7 of Set 13 | palmer
# Processing Record 8 of Set 13 | suntar
# Processing Record 9 of Set 13 | nkhotakota
# Processing Record 10 of Set 13 | ozernyy
# Processing Record 11 of Set 13 | christchurch
# Processing Record 12 of Set 13 | taos
# Processing Record 13 of Set 13 | san julian
# Processing Record 14 of Set 13 | san rafael
# Processing Record 15 of Set 13 | blackwater
# Processing Record 16 of Set 13 | guarapari
# Processing Record 17 of Set 13 | katsuren-haebaru
# Processing Record 18 of Set 13 | diplo
# Processing Record 19 of Set 13 | acarau
# Processing Record 20 of Set 13 | longonjo
# Processing Record 21 of Set 13 | chemolgan
# Processing Record 22 of Set 13 | mangai
# Processing Record 23 of Set 13 | necochea
# Processing Record 24 of Set 13 | brookings
# Processing Record 25 of Set 13 | gifford
# Processing Record 26 of Set 13 | usinsk
# Processing Record 27 of Set 13 | tippi
# Processing Record 28 of Set 13 | pimentel
# Processing Record 29 of Set 13 | manakara
# Processing Record 30 of Set 13 | durham
# Processing Record 31 of Set 13 | fort st. john
# Processing Record 32 of Set 13 | tavda
# Processing Record 33 of Set 13 | cannonvale
# Processing Record 34 of Set 13 | flowery branch
# Processing Record 35 of Set 13 | brisas de zicatela
# Processing Record 36 of Set 13 | tazacorte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data) #remember to get rid of this cell when pushing the source to prod
# Out:
# [{'City': 'vyazemskiy', 'Lat': 47.5378, 'Lng': 134.7525, 'Max Temp': 290.8, 'Humidity': 42, 'Cloudiness': 1, 'Wind Speed': 5.49, 'Country': 'RU', 'Date': 1697181458}, {'City': 'tafuna', 'Lat': -14.3358, 'Lng': -170.72, 'Max Temp': 301.12, 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 7.72, 'Country': 'AS', 'Date': 1697181458}, {'City': 'bir el hafey', 'Lat': 34.9321, 'Lng': 9.1932, 'Max Temp': 295.89, 'Humidity': 35, 'Cloudiness': 0, 'Wind Speed': 1.73, 'Country': 'TN', 'Date': 1697181458}, {'City': 'puerto natales', 'Lat': -51.7236, 'Lng': -72.4875, 'Max Temp': 277.22, 'Humidity': 96, 'Cloudiness': 52, 'Wind Speed': 2.99, 'Country': 'CL', 'Date': 1697181380}, {'City': 'fuerte olimpo', 'Lat': -21.0415, 'Lng': -57.8738, 'Max Temp': 291.67, 'Humidity': 66, 'Cloudiness': 100, 'Wind Speed': 3.7, 'Country': 'PY', 'Date': 1697181459}, {'City': 'port-aux-francais', 'Lat': -49.35, 'Lng': 70.2167, 'Max Temp': 276.14, 'Humidity': 76, 'Cloudiness': 67, 'Wind Speed': 9.91, 'Country': 'TF', 'Date': 1697181459}, {'City': 'orkney', 'Lat': -26.9802, 'Lng': 26.6727, 'Max Temp': 290.38, 'Humidity': 30, 'Cloudiness': 0, 'Wind Speed': 2.79, 'Country': 'ZA', 'Date': 1697181459}, {'City': 'atherton', 'Lat': 53.5237, 'Lng': -2.4935, 'Max Temp': 287.45, 'Humidity': 97, 'Cloudiness': 100, 'Wind Speed': 0.6, 'Country': 'GB', 'Date': 1697181460}, {'City': 'idri', 'Lat': 27.5, 'Lng': 13.2667, 'Max Temp': 296.13, 'Humidity': 38, 'Cloudiness': 0, 'Wind Speed': 4.65, 'Country': 'LY', 'Date': 1697181460}, {'City': 'adamstown', 'Lat': -25.066, 'Lng': -130.1015, 'Max Temp': 293.71, 'Humidity': 72, 'Cloudiness': 72, 'Wind Speed': 5.63, 'Country': 'PN', 'Date': 1697181460}, {'City': 'port alfred', 'Lat': -33.5906, 'Lng': 26.891, 'Max Temp': 292.69, 'Humidity': 72, 'Cloudiness': 78, 'Wind Speed': 6.26, 'Country': 'ZA', 'Date': 1697181460}, {'City': 'kete krachi', 'Lat': 7.7939, 'Lng': -0.0498, 'Max Temp': 298.47, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 1.88, 'Country': 'GH', 'Date': 1697181460}, {'City': 'la passe', 'Lat': 45.5549, 'Lng': -0.8967, 'Max Temp': 291.28, 'Humidity': 53, 'Cloudiness': 22, 'Wind Speed': 6.43, 'Country': 'FR', 'Date': 1697181461}, {'City': 'trinidad', 'Lat': -14.8333, 'Lng': -64.9, 'Max Temp': 297.33, 'Humidity': 90, 'Cloudiness': 90, 'Wind Speed': 1.85, 'Country': 'BO', 'Date': 1697181461}, {'City': 'blackmans bay', 'Lat': -43.0167, 'Lng': 147.3167, 'Max Temp': 286.33, 'Humidity': 59, 'Cloudiness': 79, 'Wind Speed': 1.34, 'Country': 'AU', 'Date': 1697181461}, {'City': 'yellowknife', 'Lat': 62.456, 'Lng': -114.3525, 'Max Temp': 280.6, 'Humidity': 100, 'Cloudiness': 100, 'Wind Speed': 3.6, 'Country': 'CA', 'Date': 1697181322}, {'City': 'invercargill', 'Lat': -46.4, 'Lng': 168.35, 'Max Temp': 289.83, 'Humidity': 56, 'Cloudiness': 100, 'Wind Speed': 4.02, 'Country': 'NZ', 'Date': 1697181461}, {'City': 'stanley', 'Lat': 54.868, 'Lng': -1.6985, 'Max Temp': 282.19, 'Humidity': 92, 'Cloudiness': 75, 'Wind Speed': 0.51, 'Country': 'GB', 'Date': 1697181462}, {'City': 'bethel', 'Lat': 41.3712, 'Lng': -73.414, 'Max Temp': 284.83, 'Humidity': 76, 'Cloudiness': 27, 'Wind Speed': 0.45, 'Country': 'US', 'Date': 1697181462}, {'City': 'soio', 'Lat': -6.1349, 'Lng': 12.3689, 'Max Temp': 299.15, 'Humidity': 80, 'Cloudiness': 84, 'Wind Speed': 3.9, 'Country': 'AO', 'Date': 1697181462}, {'City': 'dubovskoye', 'Lat': 47.4092, 'Lng': 42.7575, 'Max Temp': 284.41, 'Humidity': 36, 'Cloudiness': 100, 'Wind Speed': 4.25, 'Country': 'RU', 'Date': 1697181462}, {'City': 'waitangi', 'Lat': -43.9535, 'Lng': -176.5597, 'Max Temp': 283.05, 'Humidity': 87, 'Cloudiness': 97, 'Wind Speed': 0.89, 'Country': 'NZ', 'Date': 1697181381}, {'City': 'petropavlovsk-kamchatsky', 'Lat': 53.0452, 'Lng': 158.6483, 'Max Temp': 278.48, 'Humidity': 73, 'Cloudiness': 0, 'Wind Speed': 6.71, 'Country': 'RU', 'Date': 1697181263}, {'City': 'puerto ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max Temp': 296.34, 'Humidity': 86, 'Cloudiness': 28, 'Wind Speed': 3.23, 'Country': 'EC', 'Date' ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          615
# Lat           615
# Lng           615
# Max Temp      615
# Humidity      615
# Cloudiness    615
# Wind Speed    615
# Country       615
# Date          615
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         laojunmiao  39.8333   97.7333     44.42        27           0
# 1             tobruk  32.0836   23.9764     70.75        68           1
# 2  port-aux-francais -49.3500   70.2167     37.08        76          66
# 3             rikaze  29.2500   88.8833     40.15        66           1
# 4              sitka  57.0531 -135.3300     62.49        51         100
#
#    Wind Speed Country        Date
# 0        4.88      CN  1697233833
# 1        7.45      LY  1697233834
# 2       21.00      TF  1697233834
# 3        2.28      CN  1697233734
# 4       13.80      US  1697233661

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
# REMEMBER to include the trailing dot for directory travesal
city_data_df = pd.read_csv("./output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               laojunmiao  39.8333   97.7333     44.42        27           0
# 1                   tobruk  32.0836   23.9764     70.75        68           1
# 2        port-aux-francais -49.3500   70.2167     37.08        76          66
# 3                   rikaze  29.2500   88.8833     40.15        66           1
# 4                    sitka  57.0531 -135.3300     62.49        51         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.88      CN  1697233833
# 1              7.45      LY  1697233834
# 2             21.00      TF  1697233834
# 3              2.28      CN  1697233734
# 4             13.80      US  1697233661

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#DATE function here
endRunDate = city_data_df["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')

# %%
# Build scatter plot for latitude vs. temperature
# Remove the starter code in the cell below before moving to prod
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black', alpha=0.75)

# Add labels and other graph properties
plt.title(f'City Latitude vs. Max Temperature {runDate}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')

# Add a grid for better readability
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Scatter plot for latitude vs humidity
# Analysis: Weak correlation. It gets humid everywhere in the world
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Scatter plot for latitude vs cloudiness
# Analysis: Weak correlation 
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='red', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot for latitude vs wind speed
# Analysis: It looks like it's windier up north than south of the Earth
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='green', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save the figure
plt.savefig("./output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values, y_values, regressionEQPlotX, regressionEQPlotY, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-value is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regressionEQPlotX,regressionEQPlotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        laojunmiao  39.8333   97.7333     44.42        27           0
# 1            tobruk  32.0836   23.9764     70.75        68           1
# 3            rikaze  29.2500   88.8833     40.15        66           1
# 4             sitka  57.0531 -135.3300     62.49        51         100
# 6        georgetown   5.4112  100.3354     80.53        86          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.88      CN  1697233833
# 1              7.45      LY  1697233834
# 3              2.28      CN  1697233734
# 4             13.80      US  1697233661
# 6              3.44      MY  1697233539

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 2                  port-aux-francais -49.3500  70.2167     37.08        76
# 5                     port elizabeth -33.9180  25.5701     57.49        96
# 7                     puerto natales -51.7236 -72.4875     43.52        81
# 10       edinburgh of the seven seas -37.0676 -12.3116     58.87        95
# 11                         grytviken -54.2811 -36.5092     34.09        96
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                66       21.00      TF  1697233834
# 5                75        3.44      ZA  1697233835
# 7                37        8.84      CL  1697233835
# 10              100       28.23      SH  1697233836
# 11              100       19.84      GS  1697233758

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40

#y axis label
y_label = "Temperature (F)"

#title
plt.title(f'Northern Hemisphere Latitude vs Temp on {runDate}')

#linear regression 
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

#save as a png
plt.savefig(f'./output_data/Northern Hemisphere Latitude vs Temp on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.8412988193684108
# y = -0.84x + 92.82

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40

#y axis label
y_label = "Temperature (F)"

#title
plt.title(f'Southern Hemisphere Latitude vs Temp on {runDate}')

#linear regression 
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

#save as a png
plt.savefig(f'./output_data/Southern Hemisphere Latitude vs Temp on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.801978702328384
# y = 0.68x + 84.02

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hem Humidity v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.1421726691418762
# y = 0.16x + 64.74

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
#Southern Hem Humidity v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.08374898875251631
# y = 0.13x + 72.87

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Humidity in the Nothern and Southern hemisphere do not seem to have any correlation between humidity and the latitude of the cities in the globe.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hem Cloudiness v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Northern Hemisphere Latitude vs Cloudiness on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Northern Hemisphere Latitude vs Cloudiness on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.210333884482498
# y = 0.43x + 39.4

# %%
#Southern Hem Cloudiness v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Southern Hemisphere Latitude vs Cloudiness on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Southern Hemisphere Latitude vs Cloudiness on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.006937712575786854
# y = -0.02x + 52.06

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Based on the regression plots above, cloudiness in the Nothern and Southern Hemisphere do not seem to have any correlation at all regarding which hemisphere has more clouds/less clouds.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
#Northern Hem Wind Speed v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

regEQplotX = 45
regEQplotY = 15

y_label = "Wind Speed"

plt.title(f'Northern Hemisphere Latitude vs Wind Speed on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Northern Hemisphere Latitude vs Wind Speed on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.2791375071269216
# y = 0.08x + 4.67

# %%
#Southern Hem Wind Speed v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

regEQplotX = 45
regEQplotY = 15

y_label = "Wind Speed"

plt.title(f'Southern Hemisphere Latitude vs Wind Speed on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'./output_data/Northern Southern Latitude vs Wind Speed on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.2969811452730966
# y = -0.14x + 6.3

# %% [markdown]
# **Discussion about the linear relationship:**
#
# It mightbe that the southern hemisphere is LESS windy in concentrated latitude than the north, but it's really hard to tell.
