# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) #for testing, decrease this number to 50
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) #for testing, decrease this number to 50
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

#print(cities)
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL - Use openweather API 2.5
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Unit: standard or imperial
unit = "imperial"

# Define a limit for the number of results (adjust as needed)
limit = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&limit={limit}&appid={weather_api_key}&units={unit}"
    #f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        #print(f"{city} found")
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | kapa'a
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | aasiaat
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | incline village
# Processing Record 7 of Set 1 | stanley
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | keflavik
# Processing Record 11 of Set 1 | baharly
# Processing Record 12 of Set 1 | noumea
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | port saint john's
# Processing Record 15 of Set 1 | saudarkrokur
# Processing Record 16 of Set 1 | tsiombe
# Processing Record 17 of Set 1 | uturoa
# Processing Record 18 of Set 1 | fort bragg
# Processing Record 19 of Set 1 | samarinda
# Processing Record 20 of Set 1 | st. john's
# Processing Record 21 of Set 1 | nar'yan-mar
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | udachny
# Processing Record 24 of Set 1 | markovo
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | broken hill
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | zavolzh'ye
# Processing Record 30 of Set 1 | mbanza kongo
# Processing Record 31 of Set 1 | port-aux-francais
# Processing Record 32 of Set 1 | coronado
# Processing Record 33 of Set 1 | qaqortoq
# Processing Record 34 of Set 1 | touros
# Processing Record 35 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 36 of Set 1 | dryden
# Processing Record 37 of Set 1 | lihue
# Processing Record 38 of Set 1 | ingeniero jacobacci
# Processing Record 39 of Set 1 | amga
# Processing Record 40 of Set 1 | kirakira
# Processing Record 41 of Set 1 | srednebelaya
# Processing Record 42 of Set 1 | grytviken
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | rongelap
# Processing Record 45 of Set 1 | zholymbet
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | hawaiian paradise park
# Processing Record 48 of Set 1 | kualakapuas
# Processing Record 49 of Set 1 | wailua homesteads
# Processing Record 50 of Set 1 | kone
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | margate
# Processing Record 2 of Set 2 | fortaleza
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | erenhot
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | bhawanipatna
# Processing Record 9 of Set 2 | westport
# Processing Record 10 of Set 2 | hami
# Processing Record 11 of Set 2 | nagqu
# Processing Record 12 of Set 2 | atafu village
# Processing Record 13 of Set 2 | indramayu
# Processing Record 14 of Set 2 | edinburgh of the seven seas
# Processing Record 15 of Set 2 | merizo village
# Processing Record 16 of Set 2 | ankang
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | miyaly
# Processing Record 19 of Set 2 | west island
# Processing Record 20 of Set 2 | mulayjah
# Processing Record 21 of Set 2 | moroni
# Processing Record 22 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 24 of Set 2 | lloydminster
# Processing Record 25 of Set 2 | north bend
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | ebon
# Processing Record 28 of Set 2 | sinop
# Processing Record 29 of Set 2 | khirkiyan
# Processing Record 30 of Set 2 | port mathurin
# Processing Record 31 of Set 2 | freetown
# Processing Record 32 of Set 2 | kayangel
# Processing Record 33 of Set 2 | manado
# Processing Record 34 of Set 2 | tralee
# Processing Record 35 of Set 2 | wetteren
# Processing Record 36 of Set 2 | bonthe
# Processing Record 37 of Set 2 | howrah
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | governor's harbour
# City not found. Skipping...
# Processing Record 40 of Set 2 | hampton bays
# Processing Record 41 of Set 2 | smithers
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | skagen
# Processing Record 44 of Set 2 | thames
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | vorkuta
# Processing Record 47 of Set 2 | baukau
# Processing Record 48 of Set 2 | blackmans bay
# Processing Record 49 of Set 2 | oruro
# Processing Record 0 of Set 3 | holualoa
# Processing Record 1 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 3 | utrik
# Processing Record 3 of Set 3 | kutulik
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | rizhao
# Processing Record 6 of Set 3 | sambava
# Processing Record 7 of Set 3 | hsinchu
# Processing Record 8 of Set 3 | susuman
# Processing Record 9 of Set 3 | port macquarie
# Processing Record 10 of Set 3 | constantia
# Processing Record 11 of Set 3 | mayna
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | nuku'alofa
# Processing Record 14 of Set 3 | ivdel'
# Processing Record 15 of Set 3 | pont rouge
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | praya
# Processing Record 18 of Set 3 | olonkinbyen
# Processing Record 19 of Set 3 | rudnichnyy
# Processing Record 20 of Set 3 | ushuaia
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | phimai
# Processing Record 23 of Set 3 | golfito
# Processing Record 24 of Set 3 | oranjemund
# Processing Record 25 of Set 3 | malango
# Processing Record 26 of Set 3 | gazojak
# Processing Record 27 of Set 3 | yaya
# Processing Record 28 of Set 3 | haiku-pauwela
# Processing Record 29 of Set 3 | mizan teferi
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | bambanglipuro
# Processing Record 33 of Set 3 | yaren
# Processing Record 34 of Set 3 | tolanaro
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | yarmouth
# Processing Record 37 of Set 3 | palo santo
# Processing Record 38 of Set 3 | kigoma
# Processing Record 39 of Set 3 | villa ojo de agua
# Processing Record 40 of Set 3 | hotan
# Processing Record 41 of Set 3 | vernon
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | usinsk
# Processing Record 44 of Set 3 | talara
# Processing Record 45 of Set 3 | chulakkurgan
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | guerrero negro
# Processing Record 48 of Set 3 | guiljungan
# Processing Record 49 of Set 3 | thompson
# Processing Record 0 of Set 4 | badger
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | anadyr
# Processing Record 3 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 4 of Set 4 | mount pearl
# Processing Record 5 of Set 4 | bam
# Processing Record 6 of Set 4 | mus
# Processing Record 7 of Set 4 | manali
# Processing Record 8 of Set 4 | nizhneangarsk
# Processing Record 9 of Set 4 | suoyarvi
# Processing Record 10 of Set 4 | kuqa
# Processing Record 11 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 4 | christchurch
# Processing Record 13 of Set 4 | gadzhiyevo
# Processing Record 14 of Set 4 | envira
# Processing Record 15 of Set 4 | tura
# Processing Record 16 of Set 4 | margaret river
# Processing Record 17 of Set 4 | bozeman
# Processing Record 18 of Set 4 | mahibadhoo
# Processing Record 19 of Set 4 | pouzauges
# Processing Record 20 of Set 4 | axim
# Processing Record 21 of Set 4 | dunedin
# Processing Record 22 of Set 4 | mount isa
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | bazarnyy syzgan
# Processing Record 25 of Set 4 | weno
# Processing Record 26 of Set 4 | kuching
# Processing Record 27 of Set 4 | ijuw
# City not found. Skipping...
# Processing Record 28 of Set 4 | tuy hoa
# Processing Record 29 of Set 4 | tortona
# Processing Record 30 of Set 4 | kenai
# Processing Record 31 of Set 4 | mombetsu
# Processing Record 32 of Set 4 | seydi
# Processing Record 33 of Set 4 | bangor
# Processing Record 34 of Set 4 | vilyuchinsk
# Processing Record 35 of Set 4 | nadym
# Processing Record 36 of Set 4 | stony plain
# Processing Record 37 of Set 4 | tual
# Processing Record 38 of Set 4 | soran
# Processing Record 39 of Set 4 | enewetak
# Processing Record 40 of Set 4 | medina de pomar
# Processing Record 41 of Set 4 | puerto colombia
# Processing Record 42 of Set 4 | san antonio de pale
# Processing Record 43 of Set 4 | tachilek
# City not found. Skipping...
# Processing Record 44 of Set 4 | carolina
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | invercargill
# Processing Record 48 of Set 4 | mossel bay
# Processing Record 49 of Set 4 | jinchang
# Processing Record 0 of Set 5 | ilulissat
# Processing Record 1 of Set 5 | tumut
# Processing Record 2 of Set 5 | vorgashor
# Processing Record 3 of Set 5 | tolbazy
# Processing Record 4 of Set 5 | sabha
# Processing Record 5 of Set 5 | alice springs
# Processing Record 6 of Set 5 | pallasovka
# Processing Record 7 of Set 5 | uliastay
# Processing Record 8 of Set 5 | poso
# Processing Record 9 of Set 5 | molochnoye
# Processing Record 10 of Set 5 | plouzane
# Processing Record 11 of Set 5 | yuzhno-kurilsk
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | pitimbu
# Processing Record 14 of Set 5 | gisborne
# Processing Record 15 of Set 5 | imbituba
# Processing Record 16 of Set 5 | urzhum
# Processing Record 17 of Set 5 | benghazi
# Processing Record 18 of Set 5 | mul
# Processing Record 19 of Set 5 | vicuna mackenna
# Processing Record 20 of Set 5 | fale old settlement
# Processing Record 21 of Set 5 | brokopondo
# Processing Record 22 of Set 5 | tazovsky
# Processing Record 23 of Set 5 | kingston
# Processing Record 24 of Set 5 | al ghayzah
# Processing Record 25 of Set 5 | bushland beach
# City not found. Skipping...
# Processing Record 26 of Set 5 | puerto armuelles
# Processing Record 27 of Set 5 | altus
# Processing Record 28 of Set 5 | san
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 5 | isafjordur
# Processing Record 32 of Set 5 | tonnerre
# Processing Record 33 of Set 5 | kidal
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | yulinshi
# Processing Record 36 of Set 5 | conceicao da barra
# Processing Record 37 of Set 5 | fort st. john
# Processing Record 38 of Set 5 | fort mcmurray
# Processing Record 39 of Set 5 | presidencia roque saenz pena
# Processing Record 40 of Set 5 | ulsteinvik
# Processing Record 41 of Set 5 | hilo
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | iskateley
# Processing Record 44 of Set 5 | tumbes
# Processing Record 45 of Set 5 | marsa alam
# Processing Record 46 of Set 5 | forster
# Processing Record 47 of Set 5 | saipan
# Processing Record 48 of Set 5 | talnakh
# Processing Record 49 of Set 5 | camayenne
# Processing Record 0 of Set 6 | castillos
# Processing Record 1 of Set 6 | bom conselho
# Processing Record 2 of Set 6 | flying fish cove
# Processing Record 3 of Set 6 | vila franca do campo
# Processing Record 4 of Set 6 | cidreira
# Processing Record 5 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 6 | kikwit
# Processing Record 7 of Set 6 | mirny
# Processing Record 8 of Set 6 | lerwick
# Processing Record 9 of Set 6 | canico
# Processing Record 10 of Set 6 | bikenibeu village
# Processing Record 11 of Set 6 | ta`u
# Processing Record 12 of Set 6 | tazacorte
# Processing Record 13 of Set 6 | nuuk
# Processing Record 14 of Set 6 | ljusdal
# Processing Record 15 of Set 6 | lakatoro
# Processing Record 16 of Set 6 | agadez
# Processing Record 17 of Set 6 | belyy yar
# Processing Record 18 of Set 6 | kolwezi
# Processing Record 19 of Set 6 | sinan
# Processing Record 20 of Set 6 | khorixas
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 23 of Set 6 | kuala terengganu
# Processing Record 24 of Set 6 | antsiranana
# Processing Record 25 of Set 6 | trincomalee
# Processing Record 26 of Set 6 | gokwe
# Processing Record 27 of Set 6 | pacific grove
# Processing Record 28 of Set 6 | carbonear
# Processing Record 29 of Set 6 | ust'-uda
# Processing Record 30 of Set 6 | dudinka
# Processing Record 31 of Set 6 | tamandare
# Processing Record 32 of Set 6 | qarazhal
# Processing Record 33 of Set 6 | champerico
# Processing Record 34 of Set 6 | durres
# Processing Record 35 of Set 6 | zabaykal'sk
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 
# Processing Record 42 of Set 9 | ponta delgada
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | vastaboland
# City not found. Skipping...
# Processing Record 45 of Set 9 | labuan
# Processing Record 46 of Set 9 | cockburn town
# Processing Record 47 of Set 9 | nelson
# Processing Record 48 of Set 9 | las lomitas
# Processing Record 49 of Set 9 | chinde
# Processing Record 0 of Set 10 | greymouth
# Processing Record 1 of Set 10 | bikin
# Processing Record 2 of Set 10 | heihe
# Processing Record 3 of Set 10 | chebba
# Processing Record 4 of Set 10 | la ronge
# Processing Record 5 of Set 10 | saint croix
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | satana
# Processing Record 8 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 9 of Set 10 | bathsheba
# Processing Record 10 of Set 10 | waingapu
# Processing Record 11 of Set 10 | ndele
# Processing Record 12 of Set 10 | francisco sa
# Processing Record 13 of Set 10 | barranca
# Processing Record 14 of Set 10 | naze
# Processing Record 15 of Set 10 | shahr-e babak
# Processing Record 16 of Set 10 | bykovo
# Processing Record 17 of Set 10 | pasuquin
# Processing Record 18 of Set 10 | west bay
# Processing Record 19 of Set 10 | selkirk
# Processing Record 20 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 21 of Set 10 | tamanrasset
# Processing Record 22 of Set 10 | maloye ganyushkino
# Processing Record 23 of Set 10 | thunder bay
# Processing Record 24 of Set 10 | thurso
# Processing Record 25 of Set 10 | bou ismail
# Processing Record 26 of Set 10 | rangsdorf
# Processing Record 27 of Set 10 | aromashevo
# Processing Record 28 of Set 10 | duekoue
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | erseke
# Processing Record 31 of Set 10 | toktogul
# Processing Record 32 of Set 10 | pangkalpinang
# Processing Record 33 of Set 10 | shimabara
# Processing Record 34 of Set 10 | cannonvale
# Processing Record 35 of Set 10 | diego de almagro
# Processing Record 36 of Set 10 | horta
# Processing Record 37 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 38 of Set 10 | umluj
# Processing Record 39 of Set 10 | al kharj
# Processing Record 40 of Set 10 | darwin
# Processing Record 41 of Set 10 | kaiapoi
# Processing Record 42 of Set 10 | serdar
# Processing Record 43 of Set 10 | san rafael del sur
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | assab
# Processing Record 46 of Set 10 | olinda
# Processing Record 47 of Set 10 | vetluga
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | raduzhny
# Processing Record 0 of Set 11 | zhumysker
# Processing Record 1 of Set 11 | acapulco de juarez
# Processing Record 2 of Set 11 | pisco
# Processing Record 3 of Set 11 | nyurba
# Processing Record 4 of Set 11 | saint-francois
# Processing Record 5 of Set 11 | geidam
# Processing Record 6 of Set 11 | lethem
# Processing Record 7 of Set 11 | barra de santo antonio
# Processing Record 8 of Set 11 | tahe
# Processing Record 9 of Set 11 | anna regina
# Processing Record 10 of Set 11 | chonchi
# Processing Record 11 of Set 11 | kaa-khem
# Processing Record 12 of Set 11 | kultali
# City not found. Skipping...
# Processing Record 13 of Set 11 | balneario camboriu
# Processing Record 14 of Set 11 | happy valley-goose bay
# Processing Record 15 of Set 11 | portland
# Processing Record 16 of Set 11 | sao jose da coroa grande
# Processing Record 17 of Set 11 | santa cruz verapaz
# Processing Record 18 of Set 11 | kilindoni
# Processing Record 19 of Set 11 | leninskoye
# Processing Record 20 of Set 11 | lazarevskoye
# Processing Record 21 of Set 11 | homer
# Processing Record 22 of Set 11 | gifford
# Processing Record 23 of Set 11 | katsuura
# Processing Record 24 of Set 11 | nasielsk
# Processing Record 25 of Set 11 | queenstown
# Processing Record 26 of Set 11 | amnat charoen
# Processing Record 27 of Set 11 | marka
# Processing Record 28 of Set 11 | auki
# Processing Record 29 of Set 11 | muntok
# Processing Record 30 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 31 of Set 11 | aracena
# Processing Record 32 of Set 11 | telaga batu
# City not found. Skipping...
# Processing Record 33 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 34 of Set 11 | cootamundra
# Processing Record 35 of Set 11 | matamey
# Processing Record 36 of Set 11 | dosso
# Processing Record 37 of Set 11 | malkerns
# Processing Record 38 of Set 11 | kristinehamn
# Processing Record 39 of Set 11 | dawson creek
# Processing Record 40 of Set 11 | kununurra
# Processing Record 41 of Set 11 | nikolayevsk-on-amure
# Processing Record 42 of Set 11 | wladyslawowo
# Processing Record 43 of Set 11 | itaueira
# Processing Record 44 of Set 11 | beau vallon
# Processing Record 45 of Set 11 | kapuskasing
# Processing Record 46 of Set 11 | cururupu
# Processing Record 47 of Set 11 | east end
# Processing Record 48 of Set 11 | isesaki
# Processing Record 49 of Set 11 | digapahandi
# Processing Record 0 of Set 12 | moramanga
# Processing Record 1 of Set 12 | ibarreta
# Processing Record 2 of Set 12 | shalkar
# Processing Record 3 of Set 12 | nguigmi
# Processing Record 4 of Set 12 | lautoka
# Processing Record 5 of Set 12 | vrnograc
# Processing Record 6 of Set 12 | kogalym
# Processing Record 7 of Set 12 | tamiahua
# Processing Record 8 of Set 12 | colonia
# Processing Record 9 of Set 12 | okulovka
# Processing Record 10 of Set 12 | kars
# Processing Record 11 of Set 12 | fuerte olimpo
# Processing Record 12 of Set 12 | springs
# Processing Record 13 of Set 12 | rumoi
# Processing Record 14 of Set 12 | avarua
# Processing Record 15 of Set 12 | kiunga
# Processing Record 16 of Set 12 | bozhou
# Processing Record 17 of Set 12 | toamasina
# Processing Record 18 of Set 12 | fannuj
# City not found. Skipping...
# Processing Record 19 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 12 | rincon
# Processing Record 21 of Set 12 | shimo-furano
# Processing Record 22 of Set 12 | zuni pueblo
# Processing Record 23 of Set 12 | mitsamiouli
# Processing Record 24 of Set 12 | la gi
# Processing Record 25 of Set 12 | sangueya
# Processing Record 26 of Set 12 | graaff-reinet
# Processing Record 27 of Set 12 | saint-philippe
# Processing Record 28 of Set 12 | kudahuvadhoo
# Processing Record 29 of Set 12 | vizinga
# Processing Record 30 of Set 12 | butterworth
# Processing Record 31 of Set 12 | shaowu
# Processing Record 32 of Set 12 | loen
# Processing Record 33 of Set 12 | tindouf
# Processing Record 34 of Set 12 | megion
# Processing Record 35 of Set 12 | sierra grande
# Processing Record 36 of Set 12 | gillette
# Processing Record 37 of Set 12 | burang
# Processing Record 38 of Set 12 | port augusta
# Processing Record 39 of Set 12 | abong mbang
# Processing Record 40 of Set 12 | lengshuitan
# Processing Record 41 of Set 12 | jose bonifacio
# Processing Record 42 of Set 12 | sechura
# Processing Record 43 of Set 12 | praia
# Processing Record 44 of Set 12 | torghay
# Processing Record 45 of Set 12 | remire-montjoly
# Processing Record 46 of Set 12 | praia da vitoria
# Processing Record 47 of Set 12 | las tablas
# Processing Record 48 of Set 12 | ebaye
# Processing Record 49 of Set 12 | boyolangu
# Processing Record 0 of Set 13 | wattegama
# Processing Record 1 of Set 13 | isiro
# Processing Record 2 of Set 13 | sinabang
# Processing Record 3 of Set 13 | poronaysk
# Processing Record 4 of Set 13 | cotacachi
# Processing Record 5 of Set 13 | ambon
# Processing Record 6 of Set 13 | yantarnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_
 'Lat': 62.456, 'Lng': -114.3525, 'Max Temp': 280.6, 'Humidity': 100, 'Cloudiness': 100, 'Wind Speed': 3.6, 'Country': 'CA', 'Date': 1697181322}, {'City': 'invercargill', 'Lat': -46.4, 'Lng': 168.35, 'Max Temp': 289.83, 'Humidity': 56, 'Cloudiness': 100, 'Wind Speed': 4.02, 'Country': 'NZ', 'Date': 1697181461}, {'City': 'stanley', 'Lat': 54.868, 'Lng': -1.6985, 'Max Temp': 282.19, 'Humidity': 92, 'Cloudiness': 75, 'Wind Speed': 0.51, 'Country': 'GB', 'Date': 1697181462}, {'City': 'bethel', 'Lat': 41.3712, 'Lng': -73.414, 'Max Temp': 284.83, 'Humidity': 76, 'Cloudiness': 27, 'Wind Speed': 0.45, 'Country': 'US', 'Date': 1697181462}, {'City': 'soio', 'Lat': -6.1349, 'Lng': 12.3689, 'Max Temp': 299.15, 'Humidity': 80, 'Cloudiness': 84, 'Wind Speed': 3.9, 'Country': 'AO', 'Date': 1697181462}, {'City': 'dubovskoye', 'Lat': 47.4092, 'Lng': 42.7575, 'Max Temp': 284.41, 'Humidity': 36, 'Cloudiness': 100, 'Wind Speed': 4.25, 'Country': 'RU', 'Date': 1697181462}, {'City': 'waitangi', 'Lat': -43.9535, 'Lng': -176.5597, 'Max Temp': 283.05, 'Humidity': 87, 'Cloudiness': 97, 'Wind Speed': 0.89, 'Country': 'NZ', 'Date': 1697181381}, {'City': 'petropavlovsk-kamchatsky', 'Lat': 53.0452, 'Lng': 158.6483, 'Max Temp': 278.48, 'Humidity': 73, 'Cloudiness': 0, 'Wind Speed': 6.71, 'Country': 'RU', 'Date': 1697181263}, {'City': 'puerto ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max Temp': 296.34, 'Humidity': 86, 'Cloudiness': 28, 'Wind Speed': 3.23, 'Country': 'EC', 'Date' ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto natales -51.7236  -72.4875     38.44        96          30
# 1          kapa'a  22.0752 -159.3190     86.47        62           0
# 2          albany  42.6001  -73.9662     55.81        65          33
# 3         aasiaat  68.7098  -52.8699     29.61        99         100
# 4  ribeira grande  38.5167  -28.7000     65.77        94         100
#
#    Wind Speed Country        Date
# 0        6.91      CL  1697239834
# 1       10.36      US  1697239834
# 2        4.79      US  1697239834
# 3       12.82      GL  1697239835
# 4       15.01      PT  1697239835

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
# REMEMBER to include the trailing dot for directory travesal
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875     38.44        96          30
# 1                kapa'a  22.0752 -159.3190     86.47        62           0
# 2                albany  42.6001  -73.9662     55.81        65          33
# 3               aasiaat  68.7098  -52.8699     29.61        99         100
# 4        ribeira grande  38.5167  -28.7000     65.77        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.91      CL  1697239834
# 1             10.36      US  1697239834
# 2              4.79      US  1697239834
# 3             12.82      GL  1697239835
# 4             15.01      PT  1697239835

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#DATE function here
endRunDate = city_data_df["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')

# %%
# Build scatter plot for latitude vs. temperature
# Remove the starter code in the cell below before moving to prod
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black', alpha=0.75)

# Add labels and other graph properties
plt.title(f'City Latitude vs. Max Temperature {runDate}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')

# Add a grid for better readability
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Scatter plot for latitude vs humidity
# Analysis: Weak correlation. It gets humid everywhere in the world
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Scatter plot for latitude vs cloudiness
# Analysis: Weak correlation 
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='red', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot for latitude vs wind speed
# Analysis: It looks like it's windier up north than south of the Earth
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='green', alpha=0.75)

# Incorporate the other graph properties

plt.title('City Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values, y_values, regressionEQPlotX, regressionEQPlotY, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-value is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regressionEQPlotX,regressionEQPlotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 kapa'a  22.0752 -159.3190     86.47        62           0
# 2                 albany  42.6001  -73.9662     55.81        65          33
# 3                aasiaat  68.7098  -52.8699     29.61        99         100
# 4         ribeira grande  38.5167  -28.7000     65.77        94         100
# 5        incline village  39.2513 -119.9730     63.45        34          75
#
#          Wind Speed Country        Date
# City_ID
# 1             10.36      US  1697239834
# 2              4.79      US  1697239834
# 3             12.82      GL  1697239835
# 4             15.01      PT  1697239835
# 5             11.01      US  1697239835

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875     38.44        96          30
# 7             adamstown -25.0660 -130.1015     70.12        82         100
# 8              waitangi -43.9535 -176.5597     54.28        91          39
# 11               noumea -22.2763  166.4572     82.38        99          19
# 12         punta arenas -53.1500  -70.9167     46.51        66          20
#
#          Wind Speed Country        Date
# City_ID
# 0              6.91      CL  1697239834
# 7             15.66      PN  1697239836
# 8             30.96      NZ  1697239836
# 11             9.17      NC  1697239809
# 12            20.71      CL  1697239790

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40

#y axis label
y_label = "Temperature (F)"

#title
plt.title(f'Northern Hemisphere Latitude vs Temp on {runDate}')

#linear regression 
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

#save as a png
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Temp on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.8517432619028036
# y = -0.8x + 90.49

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40

#y axis label
y_label = "Temperature (F)"

#title
plt.title(f'Southern Hemisphere Latitude vs Temp on {runDate}')

#linear regression 
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

#save as a png
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Temp on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.8167406915558233
# y = 0.67x + 83.73

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern Hem Humidity v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.07595796508403611
# y = 0.08x + 69.37

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
#Southern Hem Humidity v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Southern Hemisphere Latitude vs Humidity on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Humidity on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.15119519272023155
# y = 0.21x + 75.08

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Humidity in the Nothern and Southern hemisphere do not seem to have any correlation between humidity and the latitude of the cities in the globe.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hem Cloudiness v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Northern Hemisphere Latitude vs Cloudiness on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Cloudiness on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.20710869599593676
# y = 0.41x + 40.15

# %%
#Southern Hem Cloudiness v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

regEQplotX = 45
regEQplotY = 15

y_label = "Humidity (%)"

plt.title(f'Southern Hemisphere Latitude vs Cloudiness on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Cloudiness on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.0016104966449772859
# y = -0.0x + 53.02

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Based on the regression plots above, cloudiness in the Nothern and Southern Hemisphere do not seem to have any correlation at all regarding which hemisphere has more clouds/less clouds.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
#Northern Hem Wind Speed v Lat Linear Reg
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

regEQplotX = 45
regEQplotY = 15

y_label = "Wind Speed"

plt.title(f'Northern Hemisphere Latitude vs Wind Speed on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Wind Speed on {runDate}.png')

plt.show()
# Out:
# The r-value is 0.2994530702661458
# y = 0.09x + 4.67

# %%
#Southern Hem Wind Speed v Lat Linear Reg
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

regEQplotX = 45
regEQplotY = 15

y_label = "Wind Speed"

plt.title(f'Southern Hemisphere Latitude vs Wind Speed on {runDate}')

linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Northern Southern Latitude vs Wind Speed on {runDate}.png')

plt.show()
# Out:
# The r-value is -0.3391304248546573
# y = -0.16x + 6.22

# %% [markdown]
# **Discussion about the linear relationship:**
#
# It mightbe that the southern hemisphere is LESS windy in concentrated latitude than the north, but it's really hard to tell.
